# %% [markdown]
# # **Pandas uygulama ödevi**

# %% [markdown]
# **Amaç:**
# Bu projede öğrencinin Pandas kütüphanesiyle veri okuma, temizleme, dönüştürme, analiz etme ve raporlama becerilerini kazanması hedeflenir.

# %% [markdown]
# **Senaryo:**
# Bir e-ticaret firmasında veri analisti olarak çalışıyorsun. Şirket, 2024 yılı satış performansını incelemek ve müşteri davranışlarını anlamak istiyor. Elinde aşağıdaki veriler var:
# orders.csv → Sipariş bilgileri
# customers.csv → Müşteri bilgileri
# products.csv → Ürün bilgileri

# %% [markdown]
# **Görevler:**
# 1. Veri Setlerini Okuma ve İnceleme
# Dosyaları Pandas ile oku.
# **head**(), **info**(), **describe**() çıktılarıyla kısa bir veri profili oluştur.
# Her veri setinde eksik değer olup olmadığını kontrol et.            kalın metin

# %% [markdown]
# **2. Veri Temizleme ve Hazırlama:**
# Aşağıdaki işlemleri uygula:
# ➤** Eksik değerler**
# Eksik müşteri bilgilerini uygun şekilde doldur veya çıkar.
# Ürün fiyatı eksik olan ürünleri belirle ve şirket politikasına göre ya ortalama fiyatla doldur ya da sil.
# ➤**Veri tipleri**
# Tarih sütunlarını datetime tipine çevir.
# Sayısal olması gereken sütunları kontrol et (fiyat, adet vb.).
# ➤ **Birleştirmeler**
# Siparişleri müşteri bilgileri ile merge et.
# Müşteri + sipariş tablosunu ürün bilgileri ile merge ederek tek bir analiz tablosu oluştur.

# %% [markdown]
# **3. Veri Analizi:**
# Aşağıdaki soruları Pandas kullanarak cevapla:
# 🛒 **Satış Analizi:**
# En çok satılan ilk 10 ürün hangileri?
# En yüksek gelir getiren kategori nedir?
# Aylara göre toplam satış gelirini hesapla (line chart önerilir).
# Sipariş başına ortalama gelir nedir?
# 👤 **Müşteri Analizi**
# Hangi müşteri en fazla alışverişi yapmış?
# Müşterileri yıllık harcama tutarlarına göre sınıflandır (ör. Bronze, Silver, Gold).
# En çok gelir getiren şehir hangisi?
# ⏱️ **Zaman Analizi**
# Günlere göre sipariş adetini bul.
# Haftanın hangi günü daha çok satış olmuş?
